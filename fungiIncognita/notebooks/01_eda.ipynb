# %% [markdown]
# # Introduction

# %% [markdown]
# Let's get started...
#
# <div style="text-align:center;">
#   <img src="../images/happycodingshroom.webp" alt="Happy coding" style="width:300px;height:auto;">
# </div>
#
# source: [giphy.com](https://giphy.com/gifs/internet-computer-typing-7TcdtHOCxo3meUvPgj)

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/secondary_data_generated_with_names.csv', sep=';')
df.head(5).T
# Out:
#                                    0               1               2  \
# family                Amanita Family  Amanita Family  Amanita Family
# name                      Fly Agaric      Fly Agaric      Fly Agaric
# class                              p               p               p
# cap-diameter                   17.14           15.48           15.19
# cap-shape                          x               f               f
# cap-surface                        h               h               g
# cap-color                          o               e               o
# does-bruise-or-bleed               f               f               f
# gill-attachment                    e               e               e
# gill-spacing                     NaN             NaN             NaN
# gill-color                         w               w               w
# stem-height                    17.94           18.49           18.06
# stem-width                     17.23           18.29           17.05
# stem-root                          s               s               s
# stem-surface                       y               y               y
# stem-color                         w               w               w
# veil-type                          u               u               u
# veil-color                         w               w               w
# has-ring                           t               t               t
# ring-type                          p               p               g
# spore-print-color                NaN             NaN             NaN
# habitat                            d               d               d
# season                             u               w               u
#
#                                    3               4
# family                Amanita Family  Amanita Family
# name                      Fly Agaric      Fly Agaric
# class                              p               p
# cap-diameter                   14.85           15.91
# cap-shape                          f               x
# cap-surface                        h               h
# cap-color                          e               e
# does-bruise-or-bleed               f               f
# gill-attachment                    e               e
# gill-spacing                     NaN             NaN
# gill-color                         w               w
# stem-height                     17.8            18.1
# stem-width                     17.08           17.57
# stem-root                          s               s
# stem-surface                       y               y
# stem-color                         w               w
# veil-type                          u               u
# veil-color                         w               w
# has-ring                           t               t
# ring-type                          g               p
# spore-print-color                NaN             NaN
# habitat                            d               d
# season                             u               w

# %%
df = df.sample(frac=1).reset_index(drop=True)
df.head(5).T
# Out:
#                                    0             1                       2  \
# family                 Bracket Fungi  Morel Family  Oyster Mushroom Family
# name                  Fuzzy Polypore  Common Morel         Oyster Mushroom
# class                              p             e                       e
# cap-diameter                   18.64          7.31                    9.98
# cap-shape                          x             o                       f
# cap-surface                        s           NaN                     NaN
# cap-color                          k             n                       g
# does-bruise-or-bleed               f             f                       f
# gill-attachment                    p             f                       d
# gill-spacing                     NaN             f                       c
# gill-color                         y             f                       y
# stem-height                     7.29          6.14                    2.49
# stem-width                      52.3         19.59                   14.18
# stem-root                        NaN           NaN                     NaN
# stem-surface                     NaN           NaN                     NaN
# stem-color                         n             n                       w
# veil-type                        NaN           NaN                     NaN
# veil-color                       NaN           NaN                     NaN
# has-ring                           f             f                       f
# ring-type                          f             f                       f
# spore-print-color                NaN           NaN                     NaN
# habitat                            d             l                       d
# season                             w             s                       a
#
#                                        3                4
# family                     Bracket Fungi  Entoloma Family
# name                  Silver Leaf Fungus   Livid Entoloma
# class                                  p                p
# cap-diameter                        2.86             8.89
# cap-shape                              o                x
# cap-surface                            l                h
# cap-color                              g                y
# does-bruise-or-bleed                   f                f
# gill-attachment                        f                s
# gill-spacing                           f              NaN
# gill-color                             f                p
# stem-height                          0.0             7.75
# stem-width                           0.0             16.8
# stem-root                              f              NaN
# stem-surface                           f                i
# stem-color                             f                n
# veil-type                            NaN              NaN
# veil-color                           NaN              NaN
# has-ring                               f                f
# ring-type                              f                f
# spore-print-color                    NaN              NaN
# habitat                                d                d
# season                                 s                a

# %%
df.shape
# Out:
# (61069, 23)

# %%
df.columns
# Out:
# Index(['family', 'name', 'class', 'cap-diameter', 'cap-shape', 'cap-surface',
#        'cap-color', 'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing',
#        'gill-color', 'stem-height', 'stem-width', 'stem-root', 'stem-surface',
#        'stem-color', 'veil-type', 'veil-color', 'has-ring', 'ring-type',
#        'spore-print-color', 'habitat', 'season'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# family                      0
# name                        0
# class                       0
# cap-diameter                0
# cap-shape                   0
# cap-surface             14120
# cap-color                   0
# does-bruise-or-bleed        0
# gill-attachment          9884
# gill-spacing            25063
# gill-color                  0
# stem-height                 0
# stem-width                  0
# stem-root               51538
# stem-surface            38124
# stem-color                  0
# veil-type               57892
# veil-color              53656
# has-ring                    0
# ring-type                2471
# spore-print-color       54715
# habitat                     0
# season                      0
# dtype: int64

# %%
# list columns with missing values
col_with_missing = df.columns[df.isna().any()].tolist()
col_with_missing

# replace missing values with "m"
df[col_with_missing] = df[col_with_missing].fillna('m')

# %%
df.name.nunique()
# Out:
# 173

# %%
for col in df.columns:
    print(f'{col}: {df[col].unique()}')
    print(f"{col} has {df[col].nunique()} unique values")
    print(f"{col} has {df[col].isna().sum()} missing values")
# Out:
# family: ['Bracket Fungi' 'Morel Family' 'Oyster Mushroom Family' 'Entoloma Family'
#  'Tricholoma Family' 'Ink Cap Family' 'Russula Family' 'Amanita Family'
#  'Paxillus Family' 'Cortinarius Family' 'Bolbitius Family' 'Bolete Family'
#  'Wax Gill Family' 'Stropharia Family' 'Jelly Discs Family'
#  'Chanterelle Family' 'Mushroom Family' 'Crepidotus Family'
#  'Hydnum Family' 'Saddle-Cup Family' 'Pluteus Family' 'Lepiota Family'
#  'Ear-Pick Family']
# family has 23 unique values
# family has 0 missing values
# name: ['Fuzzy Polypore' 'Common Morel' 'Oyster Mushroom' 'Silver Leaf Fungus'
#  'Livid Entoloma' 'Velvet Shank' 'Weeping Widow' 'Common Yellow Russula'
#  'Blackening Russula' 'Yellow Swamp Russula' 'Tawny Grisette' 'Fly Agaric'
#  'Common Crumble Cap' 'Rusty Carpet Ink Cap' 'Field Blewit'
#  'Destroying Angel' 'Brown Roll-rim' 'Common White Inocybe'
#  'Blue Leptonia' 'Brown Bell Cap' 'Blackish Purple Russula'
#  'Russet Tough Shank' 'Bonnet Bell Cap' 'Dotted-stemmed Bolete'
#  'Panther Cap' 'Ivory Wax Cap' 'Aniseed Funnel Cap' 'Magic Mushroom'
#  'Hairy Stereum' 'Tufted Bell Cap' 'Cep' "St George's Mushroom"
#  'Horse-hair Fungus' 'Clustered Tough Shank' 'Red-staining Inocybe'
#  'Changeable Melanoleuca' 'Bulbous Honey Fungus' 'The Miller'
#  'Jelly Babies' 'Ugly Milk Cap' 'Moss Pixy Cap' 'Wood Woolly-foot'
#  'Death Cap' 'Brick Caps' 'Petticoat Fungus' 'Dark-centred Hebeloma'
#  'Orange Birch Bolete' 'Scarlet Hood' 'Tubed Chanterelle'
#  'Clustered Brown Cap' 'Horn of Plenty' 'The Deceiver'
#  'Branched Oyster Mushroom' 'Fragile Russula' 'Brown Birch Bolete'
#  'Milky Bell Cap' 'Yellow Wax cap' 'White Leptonia' 'Striated Nolanea'
#  'Magpie Ink Cap' 'Beechwood Sickener' 'Straw-coloured Inocybe'
#  'Yellow-gilled Russula' 'False Death Cap' 'Yellow-stemmed Bell Cap'
#  'Peppery Milk Cap' 'Fairy Parasol' 'The Blusher' 'Hay Cap'
#  'Yellow-cracked Bolete' 'Bitter Bolete' 'Lilac Bell Cap' "Dryad's Saddle"
#  'Fleecy Milk Cap' 'The Sickener' 'Yellow-staining Mushroom'
#  'Horse Mushroom' 'Club-footed Funnel Cap' 'Soap-scented Tricholoma'
#  'Crab-scented Russula' 'Soft Slipper Toadstool' 'Slippery Jack'
#  'Coconut-scented Milk Cap' 'Blackening Wax Cap' 'Shallow-pored Bolete'
#  'Two-toned Crumble Cap' 'Little Wheel Fungus' 'Hedgehog Fungus'
#  'Greasy Tough Shank' 'Larch Bolete' 'Scaly Tricholoma'
#  'Blood-red Cortinarius' 'Bare-toothed Russula' 'Poison Pie'
#  'Stinking Russula' 'Shaggy Ink Cap' 'Parrot Wax Cap' 'White Saddle'
#  'Veined Pluteus' 'Sulphur Tuft' 'Olive-brown Panellus'
#  'Porcelain Mushroom' 'Meadow Wax Cap' 'Fawn Pluteus' 'Silky Nolanea'
#  'Cultivated Mushroom' 'Spotted Tough Shank' 'Verdigris Toadstool'
#  "Elfin's Saddle" 'False Chanterelle' "Fairies' Bonnets"
#  'False Panther Cap' 'Grey Tricholoma' 'Bay Bolete' 'Field Mushroom'
#  'Spectacular Gymnopile' 'Red-cracked Bolete' 'Rooting Shank'
#  'Sweet Milk Cap' 'Rufous Milk Cap' 'Turban Fungus' 'Purple Cortinarius'
#  'Common Funnel Cap' 'Spring Agaric' 'Shaggy Parasol' 'Woolly Milk Cap'
#  'Amethyst Deceiver' 'Rusty Wood Rotter' 'Brown Stew Fungus'
#  'Plums and custard' 'Birch Russula' 'Common Ink Cap' 'Egg Yolk Fungus'
#  'Shaggy Pholiota' 'Small Bleeding Bell Cap' 'Egg-shell Toadstool'
#  'Stinking Parasol' 'Orange Moss Agaric' 'Umbrella Navel Cap'
#  'Brown Goblet' 'Small Brown Milk Cap' 'Bleeding Brown Mushroom'
#  'Ear-pick Fungus' 'Orange Bell Cap' 'Lurid Bolete' 'Saffron Milk Cap'
#  'Fairy Ring Champignon' 'Dung Roundhead' 'Grass-green Russula'
#  'Clouded Agaric' 'Saffron Parasol' 'Wood Blewit' 'Honey Fungus'
#  'Peppery Bolete' 'Geranium-scented Russula' 'Oak Milk Cap'
#  'Velvet Roll-rim' 'Stump Bell Cap' 'Chanterelle'
#  'Yellow-brown Tricholoma' 'Red-banded Cortinarius' 'Charcoal Pholiota'
#  'Apricot Fungus' 'Glistening Ink Cap' 'Sulphur Tricholoma'
#  'Parasol Mushroom' 'Orange-red Wax Cap' 'Herald of Winter'
#  'Ivory Clitocybe' 'The Charcoal Burner' 'Spruce Milk Cap'
#  'Slimy Milk Cap' 'Parasitic Bolete']
# name has 173 unique values
# name has 0 missing values
# class: ['p' 'e']
# class has 2 unique values
# class has 0 missing values
# cap-diameter: [18.64  7.31  9.98 ... 47.45 53.35 45.19]
# cap-diameter has 2587 unique values
# cap-diameter has 0 missing values
# cap-shape: ['x' 'o' 'f' 'c' 'b' 's' 'p']
# cap-shape has 7 unique values
# cap-shape has 0 missing values
# cap-surface: ['s' 'm' 'l' 'h' 't' 'i' 'g' 'y' 'd' 'w' 'k' 'e']
# cap-surface has 12 unique values
# cap-surface has 0 missing values
# cap-color: ['k' 'n' 'g' 'y' 'o' 'e' 'w' 'u' 'b' 'r' 'l' 'p']
# cap-color has 12 unique values
# cap-color has 0 missing values
# does-bruise-or-bleed: ['f' 't']
# does-bruise-or-bleed has 2 unique values
# does-bruise-or-bleed has 0 missing values
# gill-attachment: ['p' 'f' 'd' 's' 'a' 'x' 'e' 'm']
# gill-attachment has 8 unique values
# gill-attachment has 0 missing values
# gill-spacing: ['m' 'f' 'c' 'd']
# gill-spacing has 4 unique values
# gill-spacing has 0 missing values
# gill-color: ['y' 'f' 'p' 'w' 'k' 'n' 'g' 'o' 'r' 'e' 'u' 'b']
# gill-color has 12 unique values
# gill-color has 0 missing values
# stem-height: [ 7.29  6.14  2.49 ... 25.74 20.6  18.91]
# stem-height has 2238 unique values
# stem-height has 0 missing values
# stem-width: [52.3  19.59 14.18 ... 77.14 47.67 78.61]
# stem-width has 4616 unique values
# stem-width has 0 missing values
# stem-root: ['m' 'f' 's' 'b' 'c' 'r']
# stem-root has 6 unique values
# stem-root has 0 missing values
# stem-surface: ['m' 'f' 'i' 's' 'y' 't' 'g' 'h' 'k']
# stem-surface has 9 unique values
# stem-surface has 0 missing values
# stem-color: ['n' 'w' 'f' 'o' 'g' 'u' 'y' 'r' 'k' 'p' 'e' 'l' 'b']
# stem-color has 13 unique values
# stem-color has 0 missing values
# veil-type: ['m' 'u']
# veil-type has 2 unique values
# veil-type has 0 missing values
# veil-color: ['m' 'k' 'w' 'n' 'y' 'u' 'e']
# veil-color has 7 unique values
# veil-color has 0 missing values
# has-ring: ['f' 't']
# has-ring has 2 unique values
# has-ring has 0 missing values
# ring-type: ['f' 'z' 'g' 'l' 'p' 'e' 'r' 'm']
# ring-type has 8 unique values
# ring-type has 0 missing values
# spore-print-color: ['m' 'k' 'w' 'p' 'g' 'n' 'r' 'u']
# spore-print-color has 8 unique values
# spore-print-color has 0 missing values
# habitat: ['d' 'l' 'g' 'h' 'm' 'p' 'w' 'u']
# habitat has 8 unique values
# habitat has 0 missing values
# season: ['w' 's' 'a' 'u']
# season has 4 unique values
# season has 0 missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61069 entries, 0 to 61068
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   family                61069 non-null  object
#  1   name                  61069 non-null  object
#  2   class                 61069 non-null  object
#  3   cap-diameter          61069 non-null  float64
#  4   cap-shape             61069 non-null  object
#  5   cap-surface           61069 non-null  object
#  6   cap-color             61069 non-null  object
#  7   does-bruise-or-bleed  61069 non-null  object
#  8   gill-attachment       61069 non-null  object
#  9   gill-spacing          61069 non-null  object
#  10  gill-color            61069 non-null  object
#  11  stem-height           61069 non-null  float64
#  12  stem-width            61069 non-null  float64
#  13  stem-root             61069 non-null  object
#  14  stem-surface          61069 non-null  object
#  15  stem-color            61069 non-null  object
#  16  veil-type             61069 non-null  object
#  17  veil-color            61069 non-null  object
#  18  has-ring              61069 non-null  object
#  19  ring-type             61069 non-null  object
#  20  spore-print-color     61069 non-null  object
#  21  habitat               61069 non-null  object
#  22  season                61069 non-null  object
# dtypes: float64(3), object(20)
# memory usage: 10.7+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_fuzzy_polypore = df[df['name'] == 'Fuzzy Polypore']

# %%
# Bar plots (histogramm) for cap-diameter, stem-height and stem-width
df_fuzzy_polypore.plot(kind='hist', y=['cap-diameter', 'stem-height', 'stem-width'], bins=20, alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# plot scatter plot for 'Fuzzy Polypore' cap-diameter vs stem-height,
sns.scatterplot(data=df_fuzzy_polypore, x='cap-diameter', y='stem-height', hue='name')
